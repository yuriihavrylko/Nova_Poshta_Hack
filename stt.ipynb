# %%
# !pip install nemo-toolkit[all]

# %%
import nemo.collections.asr as nemo_asr

# %%
"ua"

asr_model_ua = nemo_asr.models.ASRModel.from_pretrained("theodotus/stt_uk_squeezeformer_ctc_ml")

transcriptions_ua = asr_model_ua.transcribe(["trace_eng.m4a"])

# %%
transcriptions_ua

# %%
"en"

asr_model_en = nemo_asr.models.ASRModel.from_pretrained("nvidia/stt_en_fastconformer_transducer_xlarge")

transcriptions_en = asr_model_en.transcribe(["trace_eng.m4a"])

# %%
transcriptions_en
